# %% [markdown]
# ## Credit Risk Model

# %%
# import all the necessary Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

pd.set_option('display.float_format', lambda x : '{:.2f}'.format(x))
np.set_printoptions(suppress=True)

# %%
df_customer = pd.read_csv('datasets/customers.csv')
df_loans = pd.read_csv('datasets/loans.csv')
df_bureau = pd.read_csv('datasets/bureau_data.csv')

# %%
df_customer.shape ,df_loans.shape , df_bureau.shape
# Out:
# ((50000, 12), (50000, 15), (50000, 8))

# %%
df_customer.head()
# Out:
#   cust_id  age gender marital_status employment_status   income  \
# 0  C00001   44      M        Married     Self-Employed  2586000
# 1  C00002   38      M        Married          Salaried  1206000
# 2  C00003   46      F        Married     Self-Employed  2878000
# 3  C00004   55      F         Single     Self-Employed  3547000
# 4  C00005   37      M        Married          Salaried  3432000
#
#    number_of_dependants residence_type  years_at_current_address       city  \
# 0                     3          Owned                        27      Delhi
# 1                     3          Owned                         4    Chennai
# 2                     3          Owned                        24    Kolkata
# 3                     1          Owned                        15  Bangalore
# 4                     3          Owned                        28       Pune
#
#          state  zipcode
# 0        Delhi   110001
# 1   Tamil Nadu   600001
# 2  West Bengal   700001
# 3    Karnataka   560001
# 4  Maharashtra   411001

# %%
df_loans.head()
# Out:
#   loan_id cust_id loan_purpose  loan_type  sanction_amount  loan_amount  \
# 0  L00001  C00001         Auto    Secured          3004000      2467000
# 1  L00002  C00002         Home    Secured          4161000      3883000
# 2  L00003  C00003     Personal  Unsecured          2401000      2170000
# 3  L00004  C00004     Personal  Unsecured          2345000      1747000
# 4  L00005  C00005         Auto    Secured          4647000      4520000
#
#    processing_fee     gst  net_disbursement  loan_tenure_months  \
# 0        49340.00  444060           1973600                  33
# 1        77660.00  698940           3106400                  30
# 2        43400.00  390600           1736000                  21
# 3        34940.00  314460           1397600                   6
# 4        90400.00  813600           3616000                  28
#
#    principal_outstanding  bank_balance_at_application disbursal_date  \
# 0                1630408                       873386     2019-07-24
# 1                 709309                       464100     2019-07-24
# 2                1562399                      1476042     2019-07-24
# 3                1257839                      1031094     2019-07-24
# 4                1772334                      1032458     2019-07-24
#
#   installment_start_dt  default
# 0           2019-08-10    False
# 1           2019-08-15    False
# 2           2019-08-21    False
# 3           2019-08-09    False
# 4           2019-08-02    False

# %%
# merge customers and loans dataframe
df = pd.merge(df_customer, df_loans, on = 'cust_id')
df.head()
# Out:
#   cust_id  age gender marital_status employment_status   income  \
# 0  C00001   44      M        Married     Self-Employed  2586000
# 1  C00002   38      M        Married          Salaried  1206000
# 2  C00003   46      F        Married     Self-Employed  2878000
# 3  C00004   55      F         Single     Self-Employed  3547000
# 4  C00005   37      M        Married          Salaried  3432000
#
#    number_of_dependants residence_type  years_at_current_address       city  \
# 0                     3          Owned                        27      Delhi
# 1                     3          Owned                         4    Chennai
# 2                     3          Owned                        24    Kolkata
# 3                     1          Owned                        15  Bangalore
# 4                     3          Owned                        28       Pune
#
#    ... loan_amount  processing_fee     gst net_disbursement  \
# 0  ...     2467000        49340.00  444060          1973600
# 1  ...     3883000        77660.00  698940          3106400
# 2  ...     2170000        43400.00  390600          1736000
# 3  ...     1747000        34940.00  314460          1397600
# 4  ...     4520000        90400.00  813600          3616000
#
#   loan_tenure_months  principal_outstanding  bank_balance_at_application  \
# 0                 33                1630408                       873386
# 1                 30                 709309                       464100
# 2                 21                1562399                      1476042
# 3                  6                1257839                      1031094
# 4                 28                1772334                      1032458
#
#    disbursal_date  installment_start_dt  default
# 0      2019-07-24            2019-08-10    False
# 1      2019-07-24            2019-08-15    False
# 2      2019-07-24            2019-08-21    False
# 3      2019-07-24            2019-08-09    False
# 4      2019-07-24            2019-08-02    False
#
# [5 rows x 26 columns]

# %%
df_bureau.head(3)
# Out:
#   cust_id  number_of_open_accounts  number_of_closed_accounts  \
# 0  C00001                        1                          1
# 1  C00002                        3                          1
# 2  C00003                        2                          1
#
#    total_loan_months  delinquent_months  total_dpd  enquiry_count  \
# 0                 42                  0          0              3
# 1                 96                 12         60              5
# 2                 82                 24        147              6
#
#    credit_utilization_ratio
# 0                         7
# 1                         4
# 2                        58

# %%
# now merge df_bureau with df
df = pd.merge(df, df_bureau)
df.head()
# Out:
#   cust_id  age gender marital_status employment_status   income  \
# 0  C00001   44      M        Married     Self-Employed  2586000
# 1  C00002   38      M        Married          Salaried  1206000
# 2  C00003   46      F        Married     Self-Employed  2878000
# 3  C00004   55      F         Single     Self-Employed  3547000
# 4  C00005   37      M        Married          Salaried  3432000
#
#    number_of_dependants residence_type  years_at_current_address       city  \
# 0                     3          Owned                        27      Delhi
# 1                     3          Owned                         4    Chennai
# 2                     3          Owned                        24    Kolkata
# 3                     1          Owned                        15  Bangalore
# 4                     3          Owned                        28       Pune
#
#    ... disbursal_date  installment_start_dt default number_of_open_accounts  \
# 0  ...     2019-07-24            2019-08-10   False                       1
# 1  ...     2019-07-24            2019-08-15   False                       3
# 2  ...     2019-07-24            2019-08-21   False                       2
# 3  ...     2019-07-24            2019-08-09   False                       3
# 4  ...     2019-07-24            2019-08-02   False                       4
#
#   number_of_closed_accounts  total_loan_months  delinquent_months  total_dpd  \
# 0                         1                 42                  0          0
# 1                         1                 96                 12         60
# 2                         1                 82                 24        147
# 3                         0                115                 15         87
# 4                         2                120                  0          0
#
#    enquiry_count  credit_utilization_ratio
# 0              3                         7
# 1              5                         4
# 2              6                        58
# 3              5                        26
# 4              5                        10
#
# [5 rows x 33 columns]

# %%
df.shape
# Out:
# (50000, 33)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50000 entries, 0 to 49999
# Data columns (total 33 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   cust_id                      50000 non-null  object
#  1   age                          50000 non-null  int64
#  2   gender                       50000 non-null  object
#  3   marital_status               50000 non-null  object
#  4   employment_status            50000 non-null  object
#  5   income                       50000 non-null  int64
#  6   number_of_dependants         50000 non-null  int64
#  7   residence_type               49938 non-null  object
#  8   years_at_current_address     50000 non-null  int64
#  9   city                         50000 non-null  object
#  10  state                        50000 non-null  object
#  11  zipcode                      50000 non-null  int64
#  12  loan_id                      50000 non-null  object
#  13  loan_purpose                 50000 non-null  object
#  14  loan_type                    50000 non-null  object
#  15  sanction_amount              50000 non-null  int64
#  16  loan_amount                  50000 non-null  int64
#  17  processing_fee               50000 non-null  float64
#  18  gst                          50000 non-null  int64
#  19  net_disbursement             50000 non-null  int64
#  20  loan_tenure_months           50000 non-null  int64
#  21  principal_outstanding        50000 non-null  int64
#  22  bank_balance_at_application  50000 non-null  int64
#  23  disbursal_date               50000 non-null  object
#  24  installment_start_dt         50000 non-null  object
#  25  default                      50000 non-null  bool
#  26  number_of_open_accounts      50000 non-null  int64
#  27  number_of_closed_accounts    50000 non-null  int64
#  28  total_loan_months            50000 non-null  int64
#  29  delinquent_months            50000 non-null  int64
#  30  total_dpd                    50000 non-null  int64
#  31  enquiry_count                50000 non-null  int64
#  32  credit_utilization_ratio     50000 non-null  int64
# dtypes: bool(1), float64(1), int64(19), object(12)
# memory usage: 12.6+ MB

# %%
# converting default col from bool to int
df['default'] = df['default'].astype(int)
df['default'].value_counts()
# Out:
# 0    45703
# 1     4297
# Name: default, dtype: int64

# %% [markdown]
# `default` is a target variable and we can see some class imbalance here.

# %% [markdown]
# Generally when we are training a model, and evaluating the model performance on the test dataset, Our model performs better but when it sees a totally new data , it may not perform well. As the training dataset has some influence of test dataset. This is an overfitting problem.
#
# So the principle is whenever you are training a model, the train set should not have any influence of test set. And if there is an influence, It is called `Train Test Contamination`. That results into a data leakage problem.
#
# Another kind of data leakage is `target leakage`. This happens when some of the features which were used in train dataset are missing in the new data on which the inference is made.

# %% [markdown]
# We perform train test split before doing EDA to prevent data leakage. We don't want test set (which is part of the entire dataset) to influence EDA or any decisions on feature engineering.

# %% [markdown]
# ### Train Test Split

# %%
X = df.drop('default',axis = 1)
y = df['default']

X_train,X_test, y_train,y_test = train_test_split(X,y,test_size=0.25,random_state=42)

df_train = pd.concat([X_train,y_train], axis = 1)
df_test = pd.concat([X_test,y_test], axis = 1)

df_train.head()
# Out:
#       cust_id  age gender marital_status employment_status   income  \
# 27434  C27435   45      F         Single          Salaried  1131000
# 13400  C13401   29      M         Single          Salaried  2343000
# 883    C00884   50      F         Single     Self-Employed  2891000
# 7303   C07304   43      F         Single     Self-Employed   272000
# 45124  C45125   31      F         Single          Salaried   141000
#
#        number_of_dependants residence_type  years_at_current_address  \
# 27434                     0          Owned                         5
# 13400                     0          Owned                        25
# 883                       0       Mortgage                        29
# 7303                      1          Owned                        27
# 45124                     0          Owned                        27
#
#             city  ... disbursal_date  installment_start_dt  \
# 27434  Ahmedabad  ...     2022-04-21            2022-05-21
# 13400      Delhi  ...     2020-11-24            2020-12-11
# 883      Lucknow  ...     2019-08-25            2019-09-19
# 7303   Bangalore  ...     2020-04-16            2020-05-05
# 45124     Jaipur  ...     2024-01-26            2024-02-17
#
#       number_of_open_accounts number_of_closed_accounts total_loan_months  \
# 27434                       4                         2                90
# 13400                       3                         1               119
# 883                         2                         1                83
# 7303                        1                         1                37
# 45124                       2                         0                62
#
#        delinquent_months  total_dpd  enquiry_count  credit_utilization_ratio  \
# 27434                  6         33              8                        59
# 13400                  4         17              4                        92
# 883                   14         78              4                        83
# 7303                   0          0              5                        34
# 45124                  6         28              5                        19
#
#        default
# 27434        0
# 13400        0
# 883          0
# 7303         0
# 45124        0
#
# [5 rows x 33 columns]

# %%
df_train.shape, df_test.shape
# Out:
# ((37500, 33), (12500, 33))

# %% [markdown]
# ## Data Cleaning

# %%
# check null values
df_train.isna().sum()
# Out:
# cust_id                         0
# age                             0
# gender                          0
# marital_status                  0
# employment_status               0
# income                          0
# number_of_dependants            0
# residence_type                 48
# years_at_current_address        0
# city                            0
# state                           0
# zipcode                         0
# loan_id                         0
# loan_purpose                    0
# loan_type                       0
# sanction_amount                 0
# loan_amount                     0
# processing_fee                  0
# gst                             0
# net_disbursement                0
# loan_tenure_months              0
# principal_outstanding           0
# bank_balance_at_application     0
# disbursal_date                  0
# installment_start_dt            0
# number_of_open_accounts         0
# number_of_closed_accounts       0
# total_loan_months               0
# delinquent_months               0
# total_dpd                       0
# enquiry_count                   0
# credit_utilization_ratio        0
# default                         0
# dtype: int64

# %%
df_train['residence_type'].unique()
# Out:
# array(['Owned', 'Mortgage', 'Rented', nan], dtype=object)

# %%
df_train['residence_type'].value_counts()
# Out:
# Owned       21114
# Mortgage     8901
# Rented       7437
# Name: residence_type, dtype: int64

# %%
mode_residence = df_train['residence_type'].mode()[0]
mode_residence
# Out:
# 'Owned'

# %%
df_train['residence_type'].fillna(mode_residence,inplace = True)
df_train['residence_type'].unique()
# Out:
# array(['Owned', 'Mortgage', 'Rented'], dtype=object)

# %%
# for test dataset - replacing NA values
df_test['residence_type'].fillna(mode_residence,inplace = True)

# %%
df_train.duplicated().sum()
# Out:
# 0

# %% [markdown]
# There are no duplicate records in the training dataset

# %%
df_train.columns
# Out:
# Index(['cust_id', 'age', 'gender', 'marital_status', 'employment_status',
#        'income', 'number_of_dependants', 'residence_type',
#        'years_at_current_address', 'city', 'state', 'zipcode', 'loan_id',
#        'loan_purpose', 'loan_type', 'sanction_amount', 'loan_amount',
#        'processing_fee', 'gst', 'net_disbursement', 'loan_tenure_months',
#        'principal_outstanding', 'bank_balance_at_application',
#        'disbursal_date', 'installment_start_dt', 'number_of_open_accounts',
#        'number_of_closed_accounts', 'total_loan_months', 'delinquent_months',
#        'total_dpd', 'enquiry_count', 'credit_utilization_ratio', 'default'],
#       dtype='object')

# %%
columns_continuous = ['age',
 'income',
 'number_of_dependants',
 'years_at_current_address',
 'sanction_amount',
 'loan_amount',
 'processing_fee',
 'gst',
 'net_disbursement',
 'loan_tenure_months',
 'principal_outstanding',
 'bank_balance_at_application',
 'number_of_open_accounts',
 'number_of_closed_accounts',
 'total_loan_months',
 'delinquent_months',
 'total_dpd',
 'enquiry_count',
 'credit_utilization_ratio',]

# %%
columns_categorical = ['gender',
 'marital_status',
 'employment_status',
 'residence_type',
 'city',
 'state',
 'zipcode',
 'loan_purpose',
 'loan_type',
 'default']

# %%
# Plotting box plot for continuous features
num_plots = len(columns_continuous)
num_cols = 4  # Number of plots per row
num_rows = (num_plots + num_cols - 1) // num_cols  # Calculate the number of rows needed

fig, axes = plt.subplots(num_rows, num_cols, figsize=(5 * num_cols, 5 * num_rows))  # Adjust the figure size as needed
axes = axes.flatten()  # Flatten the axes array for easier indexing

for i, col in enumerate(columns_continuous):
    sns.boxplot(x=df_train[col], ax=axes[i])
    axes[i].set_title(col)  # Set the title to the name of the variable

# If there are any empty plots (if the number of plots isn't a perfect multiple of num_cols), hide the axes
for j in range(i + 1, num_rows * num_cols):
    axes[j].axis('off')

plt.tight_layout()
plt.show()

# %%
# Plotting histogram for continuous features
num_plots = len(columns_continuous)
num_cols = 4  # Number of plots per row
num_rows = (num_plots + num_cols - 1) // num_cols  # Calculate the number of rows needed

fig, axes = plt.subplots(num_rows, num_cols, figsize=(5 * num_cols, 5 * num_rows))  # Adjust the figure size as needed
axes = axes.flatten()  # Flatten the axes array for easier indexing

for i, col in enumerate(columns_continuous):
    sns.histplot(x=df_train[col], ax=axes[i])
    axes[i].set_title(col)  # Set the title to the name of the variable

# If there are any empty plots (if the number of plots isn't a perfect multiple of num_cols), hide the axes
for j in range(i + 1, num_rows * num_cols):
    axes[j].axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Outlier Removal: Processing Fee

# %%
df_train['processing_fee'].describe()
# Out:
# count     37500.00
# mean      80724.11
# std      120830.65
# min           0.00
# 25%       19180.00
# 50%       44700.00
# 75%       92000.00
# max     5698029.90
# Name: processing_fee, dtype: float64

# %%
df_train[df_train['processing_fee'] == df_train['processing_fee'].max()][['loan_amount','processing_fee']]
# Out:
#        loan_amount  processing_fee
# 12294      4639000      5698029.90

# %% [markdown]
# We can see here that the processing fee is greater than the loan amount

# %%
df_train[df_train['processing_fee'] > df_train['loan_amount']][['loan_amount','processing_fee']]
# Out:
#        loan_amount  processing_fee
# 23981      2234000      2669791.02
# 9898       3626000      5293543.52
# 47089      1738000      1858964.77
# 33705      3812000      5678020.86
# 12294      4639000      5698029.90
# 28174       966000      1214492.67
# 29305      2616000      3036378.01

# %% [markdown]
# Generally the Processing fee ranges between 2-3 percent of the Loan amount

# %%
df_train[(df_train['processing_fee']/df_train['loan_amount']) > 0.03][['loan_amount','processing_fee']]
# Out:
#        loan_amount  processing_fee
# 23981      2234000      2669791.02
# 9898       3626000      5293543.52
# 47089      1738000      1858964.77
# 33705      3812000      5678020.86
# 12294      4639000      5698029.90
# 28174       966000      1214492.67
# 29305      2616000      3036378.01

# %%
#we can ignore these records,
df_train1 = df_train[(df_train['processing_fee']/df_train['loan_amount']) < 0.03].copy()

# %%
#applying the same step on test set
df_test = df_test[(df_test['processing_fee']/df_test['loan_amount']) < 0.03].copy()
df_test.shape
# Out:
# (12498, 33)

# %%
# Use other business rules for data validation
# Rule 1: GST should not be more than 20%

df_train1[(df_train1.gst/df_train1.loan_amount)>0.2].shape
# Out:
# (0, 33)

# %%
# Rule 2: Net disbursement should not be higher than loan_amount
df_train1[df_train1.net_disbursement>df_train1.loan_amount].shape
# Out:
# (0, 33)

# %% [markdown]
# There are no records found where GST is more than 20% and Net disbursement is higher than loan_amount

# %% [markdown]
# ### Analyze Categorical Columns

# %%
columns_categorical
# Out:
# ['gender',
#  'marital_status',
#  'employment_status',
#  'residence_type',
#  'city',
#  'state',
#  'zipcode',
#  'loan_purpose',
#  'loan_type',
#  'default']

# %%
for col in columns_categorical:
    print(col, "-->", df_train1[col].unique())
# Out:
# gender --> ['F' 'M']
# marital_status --> ['Single' 'Married']
# employment_status --> ['Salaried' 'Self-Employed']
# residence_type --> ['Owned' 'Mortgage' 'Rented']
# city --> ['Ahmedabad' 'Delhi' 'Lucknow' 'Bangalore' 'Jaipur' 'Hyderabad' 'Kolkata'
#  'Pune' 'Chennai' 'Mumbai']
# state --> ['Gujarat' 'Delhi' 'Uttar Pradesh' 'Karnataka' 'Rajasthan' 'Telangana'
#  'West Bengal' 'Maharashtra' 'Tamil Nadu']
# zipcode --> [380001 110001 226001 560001 302001 500001 700001 411001 600001 400001]
# loan_purpose --> ['Home' 'Auto' 'Personal' 'Education' 'Personaal']
# loan_type --> ['Secured' 'Unsecured']
# default --> [0 1]

# %% [markdown]
# `loan_purpose --> ['Home' 'Auto' 'Personal' 'Education' 'Personaal']` We can see that `Personal` and `Personaal` , but it should a single category. And we will fix it

# %% [markdown]
# ### Fix Errors in Loan Purpose Column

# %%
df_train1['loan_purpose'] = df_train1['loan_purpose'].replace('Personaal', 'Personal')
df_train1['loan_purpose'].unique()
# Out:
# array(['Home', 'Auto', 'Personal', 'Education'], dtype=object)

# %%
df_test['loan_purpose'] = df_test['loan_purpose'].replace('Personaal', 'Personal')
df_test['loan_purpose'].unique()
# Out:
# array(['Education', 'Home', 'Auto', 'Personal'], dtype=object)

# %% [markdown]
# ## Exploratory Data Analysis

# %%
columns_continuous
# Out:
# ['age',
#  'income',
#  'number_of_dependants',
#  'years_at_current_address',
#  'sanction_amount',
#  'loan_amount',
#  'processing_fee',
#  'gst',
#  'net_disbursement',
#  'loan_tenure_months',
#  'principal_outstanding',
#  'bank_balance_at_application',
#  'number_of_open_accounts',
#  'number_of_closed_accounts',
#  'total_loan_months',
#  'delinquent_months',
#  'total_dpd',
#  'enquiry_count',
#  'credit_utilization_ratio']

# %%
df_train1.groupby('default')['age'].describe()
# Out:
#            count  mean  std   min   25%   50%   75%   max
# default
# 0       34298.00 39.78 9.87 18.00 33.00 40.00 47.00 70.00
# 1        3189.00 37.25 9.37 18.00 31.00 37.00 44.00 70.00

# %% [markdown]
# **Insights**
#
# 1. Average age in the default group is little less (37.25) than the average (39.78) of the group that did not default
# 1. Variability (standard deviation) is mostly similar in both the groups
# 1. Both the groups have similar min and max ages

# %%
#KDE Plot
plt.figure(figsize=(8, 4))
sns.kdeplot(df_train1['age'][df_train1['default'] == 0], fill=True, label='default=0')
sns.kdeplot(df_train1['age'][df_train1['default'] == 1], fill=True, label='default=1')
plt.title(f"Age KDE Plot with Hue by default")
plt.legend()
plt.show()

# %% [markdown]
# **Insights**
#
# 1. Orange (defaulted) group is slightly shifted to left indicating that younger folks are more likely to default on their loans

# %% [markdown]
# ### KDE for all the Continuous Columns

# %%
plt.figure(figsize=(24, 20))  # Width, height in inches

for i, col in enumerate(columns_continuous):
    plt.subplot(6, 4, i+1)  # 1 row, 4 columns, ith subplot
    sns.kdeplot(df_train1[col][df_train1['default']==0], fill=True, label='default=0')
    sns.kdeplot(df_train1[col][df_train1['default']==1], fill=True, label='default=1')
    plt.title(col) 
    plt.legend()
    plt.xlabel('')
    
plt.tight_layout()
plt.show()

# %% [markdown]
# **Insights**
#
# 1. In columns: loan_tenure_months, delinquent_months, total_dpd, credit_utilization, higher values indicate high likelyhood of becoming a default. Hence these 4 looks like strong predictors
# 1. In remaining columns the distributions do not give any obvious insights
# 1. Why loan_amount and income did not give any signs of being strong predictors?
#     - May be when we combine these two and get loan to income ratio (LTI), that may have influence on the target variable. We will explore more later

# %% [markdown]
# ### Feature Engineering & Feature Selection

# %% [markdown]
# #### Generate Loan to Income (LTI) Ratio

# %%
df_train1[["loan_amount", "income"]].head()
# Out:
#        loan_amount   income
# 27434      3276000  1131000
# 13400      2540000  2343000
# 883        1920000  2891000
# 7303        298000   272000
# 45124       260000   141000

# %%
df_train1['loan_to_income'] = round(df_train1['loan_amount'] / df_train1['income'],2)
df_train1['loan_to_income'].describe()
# Out:
# count   37487.00
# mean        1.55
# std         0.97
# min         0.30
# 25%         0.77
# 50%         1.16
# 75%         2.45
# max         4.57
# Name: loan_to_income, dtype: float64

# %%
df_test['loan_to_income'] = round(df_test['loan_amount'] / df_test['income'],2)

# %%
# Plotting KDE plot of loan_to_income ratio for both train and test set
plt.figure(figsize=(8, 4))
sns.kdeplot(df_train1['loan_to_income'][df_train1['default'] == 0], fill=True, label='default=0')
sns.kdeplot(df_train1['loan_to_income'][df_train1['default'] == 1], fill=True, label='default=1')
plt.title(f"Loan to Income Ratio (LTI) KDE Plot with Hue by default")
plt.legend()
plt.show()

# %% [markdown]
# **Insights**
# 1. Blue graph has majority of its values on lower side of LTI
# 2. Orange graph has many values when LTI is higher indicating that higher LTI means high risk loan

# %% [markdown]
# #### Generate Delinquency Ratio

# %%
#adding a new col - delinquency ratio
df_train1['delinquency_ratio'] = (df_train1['delinquent_months']*100 / df_train1['total_loan_months']).round(1)
df_test['delinquency_ratio'] = (df_test['delinquent_months']*100 / df_test['total_loan_months']).round(1)

# %%
# Plotting KDE plot of delinquency ratio for both train and test set
plt.figure(figsize=(8, 4))
sns.kdeplot(df_train1['delinquency_ratio'][df_train1['default'] == 0], fill=True, label='default=0')
sns.kdeplot(df_train1['delinquency_ratio'][df_train1['default'] == 1], fill=True, label='default=1')
plt.title(f"Delinquency Ratio KDE Plot with Hue by default")
plt.legend()
plt.show()

# %% [markdown]
# **Insights**
# 1. Blue graph has majority of its values on lower side of LTI
# 2. Orange graph has many values when delinquency ratio is higher indicating some correlation on default

# %% [markdown]
# #### Generate Avg DPD Per Delinquency

# %%
df_train1['avg_dpd_per_delinquency'] = np.where(
    df_train1['delinquent_months'] != 0,
    (df_train1['total_dpd'] / df_train1['delinquent_months']).round(1),
    0
)

df_test['avg_dpd_per_delinquency'] = np.where(
    df_test['delinquent_months'] != 0,
    (df_test['total_dpd'] / df_test['delinquent_months']).round(1),
    0
)

# %%
plt.figure(figsize=(8, 4))
sns.kdeplot(df_train1['avg_dpd_per_delinquency'][df_train1['default'] == 0], fill=True, label='default=0')
sns.kdeplot(df_train1['avg_dpd_per_delinquency'][df_train1['default'] == 1], fill=True, label='default=1')
plt.title(f"Avg DPD Per Delinquency Ratio KDE Plot with Hue by default")
plt.legend()
plt.show()

# %% [markdown]
# **Insights**
#
# 1. Graph clearly shows more occurances of default cases when avg_dpd_per_delinquency is high. This means this column is a strong predictor

# %% [markdown]
# ##### Remove columns that are just unique ids and don't have influence on target

# %%
df_train1.columns
# Out:
# Index(['cust_id', 'age', 'gender', 'marital_status', 'employment_status',
#        'income', 'number_of_dependants', 'residence_type',
#        'years_at_current_address', 'city', 'state', 'zipcode', 'loan_id',
#        'loan_purpose', 'loan_type', 'sanction_amount', 'loan_amount',
#        'processing_fee', 'gst', 'net_disbursement', 'loan_tenure_months',
#        'principal_outstanding', 'bank_balance_at_application',
#        'disbursal_date', 'installment_start_dt', 'number_of_open_accounts',
#        'number_of_closed_accounts', 'total_loan_months', 'delinquent_months',
#        'total_dpd', 'enquiry_count', 'credit_utilization_ratio', 'default',
#        'loan_to_income', 'delinquency_ratio', 'avg_dpd_per_delinquency'],
#       dtype='object')

# %%
df_train_2 = df_train1.drop(['cust_id', 'loan_id'],axis="columns")
df_test = df_test.drop(['cust_id', 'loan_id'],axis="columns")

# %% [markdown]
# ##### Remove columns that business contact person asked us to remove

# %%
df_train_3 = df_train_2.drop(['disbursal_date', 'installment_start_dt', 'loan_amount', 'income', 
                              'total_loan_months', 'delinquent_months', 'total_dpd'], axis="columns")
df_test = df_test.drop(['disbursal_date', 'installment_start_dt', 'loan_amount', 'income', 
                              'total_loan_months', 'delinquent_months', 'total_dpd'], axis="columns")
df_train_3.columns
# Out:
# Index(['age', 'gender', 'marital_status', 'employment_status',
#        'number_of_dependants', 'residence_type', 'years_at_current_address',
#        'city', 'state', 'zipcode', 'loan_purpose', 'loan_type',
#        'sanction_amount', 'processing_fee', 'gst', 'net_disbursement',
#        'loan_tenure_months', 'principal_outstanding',
#        'bank_balance_at_application', 'number_of_open_accounts',
#        'number_of_closed_accounts', 'enquiry_count',
#        'credit_utilization_ratio', 'default', 'loan_to_income',
#        'delinquency_ratio', 'avg_dpd_per_delinquency'],
#       dtype='object')

# %%
df_train_3.select_dtypes(['int64', 'float64']).columns
# Out:
# Index(['age', 'number_of_dependants', 'years_at_current_address', 'zipcode',
#        'sanction_amount', 'processing_fee', 'gst', 'net_disbursement',
#        'loan_tenure_months', 'principal_outstanding',
#        'bank_balance_at_application', 'number_of_open_accounts',
#        'number_of_closed_accounts', 'enquiry_count',
#        'credit_utilization_ratio', 'loan_to_income', 'delinquency_ratio',
#        'avg_dpd_per_delinquency'],
#       dtype='object')

# %% [markdown]
# ### VIF to measure multicolinearity

# %%
X_train = df_train_3.drop('default', axis='columns')
y_train = df_train_3['default']

from sklearn.preprocessing import MinMaxScaler

cols_to_scale = X_train.select_dtypes(['int64', 'float64']).columns

scaler = MinMaxScaler()

X_train[cols_to_scale] = scaler.fit_transform(X_train[cols_to_scale])
X_train.describe()
# Out:
#            age  number_of_dependants  years_at_current_address  zipcode  \
# count 37487.00              37487.00                  37487.00 37487.00
# mean      0.41                  0.39                      0.50     0.52
# std       0.19                  0.31                      0.30     0.29
# min       0.00                  0.00                      0.00     0.00
# 25%       0.29                  0.00                      0.23     0.33
# 50%       0.42                  0.40                      0.50     0.49
# 75%       0.54                  0.60                      0.77     0.76
# max       1.00                  1.00                      1.00     1.00
#
#        sanction_amount  processing_fee      gst  net_disbursement  \
# count         37487.00        37487.00 37487.00          37487.00
# mean              0.09            0.08     0.08              0.08
# std               0.12            0.11     0.11              0.11
# min               0.00            0.00     0.00              0.00
# 25%               0.02            0.02     0.02              0.02
# 50%               0.05            0.05     0.05              0.05
# 75%               0.10            0.10     0.10              0.10
# max               1.00            1.00     1.00              1.00
#
#        loan_tenure_months  principal_outstanding  bank_balance_at_application  \
# count            37487.00               37487.00                     37487.00
# mean                 0.38                   0.26                         0.12
# std                  0.23                   0.24                         0.13
# min                  0.00                   0.00                         0.00
# 25%                  0.19                   0.08                         0.03
# 50%                  0.34                   0.19                         0.08
# 75%                  0.55                   0.35                         0.16
# max                  1.00                   1.00                         1.00
#
#        number_of_open_accounts  number_of_closed_accounts  enquiry_count  \
# count                 37487.00                   37487.00       37487.00
# mean                      0.50                       0.50           0.50
# std                       0.37                       0.41           0.25
# min                       0.00                       0.00           0.00
# 25%                       0.00                       0.00           0.38
# 50%                       0.33                       0.50           0.50
# 75%                       0.67                       1.00           0.62
# max                       1.00                       1.00           1.00
#
#        credit_utilization_ratio  loan_to_income  delinquency_ratio  \
# count                  37487.00        37487.00           37487.00
# mean                       0.44            0.29               0.10
# std                        0.30            0.23               0.17
# min                        0.00            0.00               0.00
# 25%                        0.18            0.11               0.00
# 50%                        0.39            0.20               0.04
# 75%                        0.68            0.50               0.13
# max                        1.00            1.00               1.00
#
#        avg_dpd_per_delinquency
# count                 37487.00
# mean                      0.33
# std                       0.29
# min                       0.00
# 25%                       0.00
# 50%                       0.43
# 75%                       0.58
# max                       1.00

# %%
#### Same transformation on test set
X_test = df_test.drop('default', axis='columns')
y_test = df_test['default']

X_test[cols_to_scale] = scaler.transform(X_test[cols_to_scale])
X_test.describe()
# Out:
#            age  number_of_dependants  years_at_current_address  zipcode  \
# count 12498.00              12498.00                  12498.00 12498.00
# mean      0.41                  0.39                      0.50     0.53
# std       0.19                  0.31                      0.30     0.29
# min       0.00                  0.00                      0.00     0.00
# 25%       0.29                  0.00                      0.23     0.33
# 50%       0.42                  0.40                      0.50     0.51
# 75%       0.54                  0.60                      0.77     0.76
# max       1.00                  1.00                      1.00     1.00
#
#        sanction_amount  processing_fee      gst  net_disbursement  \
# count         12498.00        12498.00 12498.00          12498.00
# mean              0.09            0.08     0.08              0.08
# std               0.12            0.11     0.11              0.11
# min               0.00            0.00     0.00              0.00
# 25%               0.02            0.02     0.02              0.02
# 50%               0.05            0.05     0.05              0.05
# 75%               0.10            0.10     0.10              0.10
# max               0.95            1.00     1.00              1.00
#
#        loan_tenure_months  principal_outstanding  bank_balance_at_application  \
# count            12498.00               12498.00                     12498.00
# mean                 0.38                   0.26                         0.12
# std                  0.24                   0.25                         0.13
# min                  0.00                  -0.00                         0.00
# 25%                  0.19                   0.08                         0.03
# 50%                  0.36                   0.20                         0.08
# 75%                  0.55                   0.35                         0.16
# max                  1.00                   1.00                         0.88
#
#        number_of_open_accounts  number_of_closed_accounts  enquiry_count  \
# count                 12498.00                   12498.00       12498.00
# mean                      0.50                       0.51           0.50
# std                       0.37                       0.41           0.26
# min                       0.00                       0.00           0.00
# 25%                       0.00                       0.00           0.38
# 50%                       0.67                       0.50           0.50
# 75%                       1.00                       1.00           0.75
# max                       1.00                       1.00           1.00
#
#        credit_utilization_ratio  loan_to_income  delinquency_ratio  \
# count                  12498.00        12498.00           12498.00
# mean                       0.44            0.29               0.10
# std                        0.30            0.23               0.17
# min                        0.00            0.00               0.00
# 25%                        0.18            0.11               0.00
# 50%                        0.39            0.20               0.04
# 75%                        0.68            0.50               0.13
# max                        1.00            1.00               1.00
#
#        avg_dpd_per_delinquency
# count                 12498.00
# mean                      0.33
# std                       0.29
# min                       0.00
# 25%                       0.00
# 50%                       0.43
# 75%                       0.58
# max                       1.00

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

def calculate_vif(data):
    vif_df = pd.DataFrame()
    vif_df['Column'] = data.columns
    vif_df['VIF'] = [variance_inflation_factor(data.values,i) for i in range(data.shape[1])]
    return vif_df

# %%
X_train.head()
# Out:
#        age gender marital_status employment_status  number_of_dependants  \
# 27434 0.52      F         Single          Salaried                  0.00
# 13400 0.21      M         Single          Salaried                  0.00
# 883   0.62      F         Single     Self-Employed                  0.00
# 7303  0.48      F         Single     Self-Employed                  0.20
# 45124 0.25      F         Single          Salaried                  0.00
#
#       residence_type  years_at_current_address       city          state  \
# 27434          Owned                      0.13  Ahmedabad        Gujarat
# 13400          Owned                      0.80      Delhi          Delhi
# 883         Mortgage                      0.93    Lucknow  Uttar Pradesh
# 7303           Owned                      0.87  Bangalore      Karnataka
# 45124          Owned                      0.87     Jaipur      Rajasthan
#
#        zipcode  ... loan_tenure_months principal_outstanding  \
# 27434     0.46  ...               0.34                  0.18
# 13400     0.00  ...               0.51                  0.20
# 883       0.20  ...               0.25                  0.27
# 7303      0.76  ...               0.28                  0.03
# 45124     0.33  ...               0.74                  0.01
#
#        bank_balance_at_application  number_of_open_accounts  \
# 27434                         0.07                     1.00
# 13400                         0.12                     0.67
# 883                           0.10                     0.33
# 7303                          0.01                     0.00
# 45124                         0.01                     0.33
#
#        number_of_closed_accounts  enquiry_count  credit_utilization_ratio  \
# 27434                       1.00           0.88                      0.60
# 13400                       0.50           0.38                      0.93
# 883                         0.50           0.38                      0.84
# 7303                        0.50           0.50                      0.34
# 45124                       0.00           0.50                      0.19
#
#        loan_to_income  delinquency_ratio  avg_dpd_per_delinquency
# 27434            0.61               0.07                     0.55
# 13400            0.18               0.03                     0.42
# 883              0.08               0.17                     0.56
# 7303             0.19               0.00                     0.00
# 45124            0.36               0.10                     0.47
#
# [5 rows x 26 columns]

# %%
calculate_vif(X_train[cols_to_scale])
# Out:
# C:\Users\Rakesh_PC\anaconda3\lib\site-packages\statsmodels\stats\outliers_influence.py:195: RuntimeWarning: divide by zero encountered in double_scalars
#   vif = 1. / (1. - r_squared_i)
#                          Column    VIF
# 0                           age   5.72
# 1          number_of_dependants   2.73
# 2      years_at_current_address   3.42
# 3                       zipcode   3.79
# 4               sanction_amount 102.15
# 5                processing_fee    inf
# 6                           gst    inf
# 7              net_disbursement    inf
# 8            loan_tenure_months   6.14
# 9         principal_outstanding  16.28
# 10  bank_balance_at_application   9.28
# 11      number_of_open_accounts   4.35
# 12    number_of_closed_accounts   2.36
# 13                enquiry_count   6.40
# 14     credit_utilization_ratio   2.93
# 15               loan_to_income   6.92
# 16            delinquency_ratio   1.95
# 17      avg_dpd_per_delinquency   2.93

# %%
# dropping features which has VIF > 10 or inf
features_to_drop_vif = ['sanction_amount', 'processing_fee', 'gst', 'net_disbursement','principal_outstanding']


X_train_1 = X_train.drop(features_to_drop_vif, axis='columns')
numeric_columns = X_train_1.select_dtypes(['int64', 'float64']).columns
numeric_columns
# Out:
# Index(['age', 'number_of_dependants', 'years_at_current_address', 'zipcode',
#        'loan_tenure_months', 'bank_balance_at_application',
#        'number_of_open_accounts', 'number_of_closed_accounts', 'enquiry_count',
#        'credit_utilization_ratio', 'loan_to_income', 'delinquency_ratio',
#        'avg_dpd_per_delinquency'],
#       dtype='object')

# %%
calculate_vif(X_train_1[numeric_columns])
# Out:
#                          Column  VIF
# 0                           age 5.45
# 1          number_of_dependants 2.73
# 2      years_at_current_address 3.41
# 3                       zipcode 3.77
# 4            loan_tenure_months 5.98
# 5   bank_balance_at_application 1.80
# 6       number_of_open_accounts 4.32
# 7     number_of_closed_accounts 2.35
# 8                 enquiry_count 6.37
# 9      credit_utilization_ratio 2.92
# 10               loan_to_income 4.53
# 11            delinquency_ratio 1.95
# 12      avg_dpd_per_delinquency 2.93

# %%
numeric_columns
# Out:
# Index(['age', 'number_of_dependants', 'years_at_current_address', 'zipcode',
#        'loan_tenure_months', 'bank_balance_at_application',
#        'number_of_open_accounts', 'number_of_closed_accounts', 'enquiry_count',
#        'credit_utilization_ratio', 'loan_to_income', 'delinquency_ratio',
#        'avg_dpd_per_delinquency'],
#       dtype='object')

# %%
plt.figure(figsize=(12,12))
cm = df_train_3[numeric_columns.append(pd.Index(['default']))].corr()
sns.heatmap(cm, annot=True, fmt='0.2f')
plt.xticks(rotation=45, ha='right')
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Feature Selection: Categorical Features

# %%
def calculate_woe_iv(df, feature, target):
    grouped = df.groupby(feature)[target].agg(['count','sum'])
    grouped = grouped.rename(columns={'count': 'total', 'sum': 'good'})
    grouped['bad']=grouped['total']-grouped['good']
    
    total_good = grouped['good'].sum()
    total_bad = grouped['bad'].sum()
    
    grouped['good_pct'] = grouped['good'] / total_good
    grouped['bad_pct'] = grouped['bad'] / total_bad
    grouped['woe'] = np.log(grouped['good_pct']/ grouped['bad_pct'])
    grouped['iv'] = (grouped['good_pct'] -grouped['bad_pct'])*grouped['woe']
    
    grouped['woe'] = grouped['woe'].replace([np.inf, -np.inf], 0)
    grouped['iv'] = grouped['iv'].replace([np.inf, -np.inf], 0)
    
    total_iv = grouped['iv'].sum()
    
    return grouped, total_iv

grouped, total_iv = calculate_woe_iv(pd.concat([X_train_1, y_train],axis=1), 'loan_purpose', 'default')
grouped
# Out:
#               total  good    bad  good_pct  bad_pct   woe   iv
# loan_purpose
# Auto           7437   314   7123      0.10     0.21 -0.75 0.08
# Education      5626   546   5080      0.17     0.15  0.14 0.00
# Home          11271  1744   9527      0.55     0.28  0.68 0.18
# Personal      13153   585  12568      0.18     0.37 -0.69 0.13

# %%
X_train_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 37487 entries, 27434 to 15795
# Data columns (total 21 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   age                          37487 non-null  float64
#  1   gender                       37487 non-null  object
#  2   marital_status               37487 non-null  object
#  3   employment_status            37487 non-null  object
#  4   number_of_dependants         37487 non-null  float64
#  5   residence_type               37487 non-null  object
#  6   years_at_current_address     37487 non-null  float64
#  7   city                         37487 non-null  object
#  8   state                        37487 non-null  object
#  9   zipcode                      37487 non-null  float64
#  10  loan_purpose                 37487 non-null  object
#  11  loan_type                    37487 non-null  object
#  12  loan_tenure_months           37487 non-null  float64
#  13  bank_balance_at_application  37487 non-null  float64
#  14  number_of_open_accounts      37487 non-null  float64
#  15  number_of_closed_accounts    37487 non-null  float64
#  16  enquiry_count                37487 non-null  float64
#  17  credit_utilization_ratio     37487 non-null  float64
#  18  loan_to_income               37487 non-null  float64
#  19  delinquency_ratio            37487 non-null  float64
#  20  avg_dpd_per_delinquency      37487 non-null  float64
# dtypes: float64(13), object(8)
# memory usage: 6.3+ MB

# %%
iv_values = {}

for feature in X_train_1.columns:
    if X_train_1[feature].dtype == 'object':
        _, iv = calculate_woe_iv(pd.concat([X_train_1, y_train],axis=1), feature, 'default' )
    else:
        X_binned = pd.cut(X_train_1[feature], bins=10, labels=False)
        _, iv = calculate_woe_iv(pd.concat([X_binned, y_train],axis=1), feature, 'default' )
    iv_values[feature] = iv
        
iv_values
# Out:
# {'age': 0.07592687127752061,
#  'gender': 0.000482276463421216,
#  'marital_status': 0.002196681370832318,
#  'employment_status': 0.002447818101774487,
#  'number_of_dependants': 0.00364589452118596,
#  'residence_type': 0.2594019617563985,
#  'years_at_current_address': 0.001042536380353028,
#  'city': 0.000817870465334103,
#  'state': 0.0007881984519711978,
#  'zipcode': 0.0007436024782513755,
#  'loan_purpose': 0.39377543144164784,
#  'loan_type': 0.17304705897793143,
#  'loan_tenure_months': 0.23450610202970526,
#  'bank_balance_at_application': 0.004242001247914226,
#  'number_of_open_accounts': 0.07324250836253295,
#  'number_of_closed_accounts': 0.00026280824021760536,
#  'enquiry_count': 0.005484982638303533,
#  'credit_utilization_ratio': 2.4228228499400095,
#  'loan_to_income': 0.4915664145044282,
#  'delinquency_ratio': 0.678322540101926,
#  'avg_dpd_per_delinquency': 0.4210029044696208}

# %%
pd.set_option('display.float_format', lambda x: '{:.3f}'.format(x))

iv_df = pd.DataFrame(list(iv_values.items()), columns=['Feature', 'IV'])
iv_df = iv_df.sort_values(by='IV', ascending=False)
iv_df
# Out:
#                         Feature    IV
# 17     credit_utilization_ratio 2.423
# 19            delinquency_ratio 0.678
# 18               loan_to_income 0.492
# 20      avg_dpd_per_delinquency 0.421
# 10                 loan_purpose 0.394
# 5                residence_type 0.259
# 12           loan_tenure_months 0.235
# 11                    loan_type 0.173
# 0                           age 0.076
# 14      number_of_open_accounts 0.073
# 16                enquiry_count 0.005
# 13  bank_balance_at_application 0.004
# 4          number_of_dependants 0.004
# 3             employment_status 0.002
# 2                marital_status 0.002
# 6      years_at_current_address 0.001
# 7                          city 0.001
# 8                         state 0.001
# 9                       zipcode 0.001
# 1                        gender 0.000
# 15    number_of_closed_accounts 0.000

# %%
# select features that has IV > 0.02
selected_features_iv = [feature for feature, iv in iv_values.items() if iv > 0.02]
selected_features_iv
# Out:
# ['age',
#  'residence_type',
#  'loan_purpose',
#  'loan_type',
#  'loan_tenure_months',
#  'number_of_open_accounts',
#  'credit_utilization_ratio',
#  'loan_to_income',
#  'delinquency_ratio',
#  'avg_dpd_per_delinquency']

# %% [markdown]
# ### Feature Encoding

# %%
X_train_reduced = X_train_1[selected_features_iv]
X_test_reduced = X_test[selected_features_iv]

# %%
X_train_encoded = pd.get_dummies(X_train_reduced, drop_first=True)
X_train_encoded.head(3)
# Out:
#         age  loan_tenure_months  number_of_open_accounts  \
# 27434 0.519               0.340                    1.000
# 13400 0.212               0.509                    0.667
# 883   0.615               0.245                    0.333
#
#        credit_utilization_ratio  loan_to_income  delinquency_ratio  \
# 27434                     0.596           0.609              0.067
# 13400                     0.929           0.183              0.034
# 883                       0.838           0.084              0.169
#
#        avg_dpd_per_delinquency  residence_type_Owned  residence_type_Rented  \
# 27434                    0.550                     1                      0
# 13400                    0.420                     1                      0
# 883                      0.560                     0                      0
#
#        loan_purpose_Education  loan_purpose_Home  loan_purpose_Personal  \
# 27434                       0                  1                      0
# 13400                       0                  0                      0
# 883                         0                  0                      1
#
#        loan_type_Unsecured
# 27434                    0
# 13400                    0
# 883                      1

# %%
X_test_encoded = pd.get_dummies(X_test_reduced, drop_first=True)
X_test_encoded.head(3)
# Out:
#         age  loan_tenure_months  number_of_open_accounts  \
# 33553 0.346               0.528                    0.333
# 9427  0.288               0.623                    1.000
# 199   0.192               0.623                    1.000
#
#        credit_utilization_ratio  loan_to_income  delinquency_ratio  \
# 33553                     0.121           0.258              0.043
# 9427                      0.859           0.689              0.000
# 199                       0.727           0.635              0.000
#
#        avg_dpd_per_delinquency  residence_type_Owned  residence_type_Rented  \
# 33553                    0.900                     1                      0
# 9427                     0.000                     1                      0
# 199                      0.000                     1                      0
#
#        loan_purpose_Education  loan_purpose_Home  loan_purpose_Personal  \
# 33553                       1                  0                      0
# 9427                        0                  1                      0
# 199                         0                  1                      0
#
#        loan_type_Unsecured
# 33553                    0
# 9427                     0
# 199                      0

# %% [markdown]
# ## Model Training

# %% [markdown]
# ### Attempt 1
#
# 1. Logistic Regression, RandomForest & XGB
# 1. No handling of class imbalance

# %%
# Training model using Logistic Regression
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report

model = LogisticRegression()
model.fit(X_train_encoded, y_train)

y_pred = model.predict(X_test_encoded)
report = classification_report(y_test, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98     11390
#            1       0.84      0.69      0.76      1108
#
#     accuracy                           0.96     12498
#    macro avg       0.90      0.84      0.87     12498
# weighted avg       0.96      0.96      0.96     12498

# %%
feature_importance = model.coef_[0]

# Create a DataFrame for easier handling
coef_df = pd.DataFrame(feature_importance, index=X_train_encoded.columns, columns=['Coefficients'])

# Sort the coefficients for better visualization
coef_df = coef_df.sort_values(by='Coefficients', ascending=True)

# Plotting
plt.figure(figsize=(8, 4))
plt.barh(coef_df.index, coef_df['Coefficients'], color='steelblue')
plt.xlabel('Coefficient Value')
plt.title('Feature Importance in Logistic Regression')
plt.show()

# %%
#Training model using RandomForest
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier()
model.fit(X_train_encoded, y_train)

y_pred = model.predict(X_test_encoded)
report = classification_report(y_test, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98     11390
#            1       0.84      0.70      0.76      1108
#
#     accuracy                           0.96     12498
#    macro avg       0.91      0.84      0.87     12498
# weighted avg       0.96      0.96      0.96     12498

# %%
#Training Model using XGBoost
from xgboost import XGBClassifier

model = XGBClassifier()
model.fit(X_train_encoded, y_train)

y_pred = model.predict(X_test_encoded)
report = classification_report(y_test, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98     11390
#            1       0.83      0.73      0.78      1108
#
#     accuracy                           0.96     12498
#    macro avg       0.90      0.86      0.88     12498
# weighted avg       0.96      0.96      0.96     12498

# %% [markdown]
# Since there is not much difference between XGB and Logistic, we will choose LogisticRegression as a candidate for our RandomizedSearchCV candidate it has a better interpretation.
#
# Train and Fine-tune the model. Here are the Success Criteria:
# 1. Recall on Default Class > 90%
# 2. Precision should be higher than 50% on the default class.

# %% [markdown]
# #### RandomizedSearchCV for Attempt 1: Logistic Regression

# %%
from sklearn.model_selection import RandomizedSearchCV

param_dist = {
    'C': np.logspace(-4, 4, 20),  # Logarithmically spaced values from 10^-4 to 10^4
    'solver': ['lbfgs', 'saga', 'liblinear', 'newton-cg']   # Algorithm to use in the optimization problem
}

# Create the Logistic Regression model
log_reg = LogisticRegression(max_iter=10000)  # Increased max_iter for convergence

# Set up RandomizedSearchCV
random_search = RandomizedSearchCV(
    estimator=log_reg,
    param_distributions=param_dist,
    n_iter=50,  # Number of parameter settings that are sampled
    scoring='f1',
    cv=3,  # 5-fold cross-validation
    verbose=2,
    random_state=42,  # Set a random state for reproducibility
    n_jobs=-1  # Use all available cores
)

# Fit the RandomizedSearchCV to the training data
random_search.fit(X_train_encoded, y_train)

# Print the best parameters and best score
print(f"Best Parameters: {random_search.best_params_}")
print(f"Best Score: {random_search.best_score_}")

best_model = random_search.best_estimator_
y_pred = best_model.predict(X_test_encoded)
print("Classification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Fitting 3 folds for each of 50 candidates, totalling 150 fits
# Best Parameters: {'solver': 'liblinear', 'C': 29.763514416313132}
# Best Score: 0.7628897930994731
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98     11390
#            1       0.83      0.71      0.77      1108
#
#     accuracy                           0.96     12498
#    macro avg       0.90      0.85      0.87     12498
# weighted avg       0.96      0.96      0.96     12498

# %% [markdown]
# #### RandomizedSearch CV for Attempt 1: XGBoost

# %%
from scipy.stats import uniform, randint
from sklearn.model_selection import RandomizedSearchCV

# Define parameter distribution for RandomizedSearchCV
param_dist = {
    'n_estimators': [100, 150, 200, 250, 300],
    'max_depth': [3, 4, 5, 6, 7, 8, 9, 10],
    'learning_rate': [0.01, 0.03, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3],
    'subsample': [0.6, 0.7, 0.8, 0.9, 1.0],
    'colsample_bytree': [0.6, 0.7, 0.8, 0.9, 1.0],
    'scale_pos_weight': [1, 2, 3, 5, 7, 10],
    'reg_alpha': [0.01, 0.1, 0.5, 1.0, 5.0, 10.0],  # L1 regularization term
    'reg_lambda': [0.01, 0.1, 0.5, 1.0, 5.0, 10.0]  # L2 regularization term
}

xgb = XGBClassifier()

random_search = RandomizedSearchCV(estimator=xgb, param_distributions=param_dist, n_iter=100,
                                   scoring='f1', cv=3, verbose=1, n_jobs=-1, random_state=42)

random_search.fit(X_train_encoded, y_train)

# Print the best parameters and best score
print(f"Best Parameters: {random_search.best_params_}")
print(f"Best Score: {random_search.best_score_}")

best_model = random_search.best_estimator_
y_pred = best_model.predict(X_test_encoded)
print("Classification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# Best Parameters: {'subsample': 0.8, 'scale_pos_weight': 2, 'reg_lambda': 1.0, 'reg_alpha': 5.0, 'n_estimators': 100, 'max_depth': 3, 'learning_rate': 0.2, 'colsample_bytree': 0.9}
# Best Score: 0.7923440532888169
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98     11390
#            1       0.78      0.82      0.80      1108
#
#     accuracy                           0.96     12498
#    macro avg       0.88      0.90      0.89     12498
# weighted avg       0.96      0.96      0.96     12498

# %% [markdown]
# ### Attempt 2
#
# 1. Logistic Regression & XGB
# 1. Handle Class Imbalance Using Under Sampling

# %%
#Handling class imbalance using underSampling
from imblearn.under_sampling import RandomUnderSampler

rus = RandomUnderSampler(random_state=42)
X_train_res, y_train_res = rus.fit_resample(X_train_encoded, y_train)
y_train_res.value_counts()
# Out:
# 0    3189
# 1    3189
# Name: default, dtype: int64

# %%
# Training model using Logistic Regression
model = LogisticRegression()
model.fit(X_train_res, y_train_res)

y_pred = model.predict(X_test_encoded)
report = classification_report(y_test, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.92      0.96     11390
#            1       0.53      0.95      0.68      1108
#
#     accuracy                           0.92     12498
#    macro avg       0.76      0.93      0.82     12498
# weighted avg       0.95      0.92      0.93     12498

# %%
# Training model using XGBoost
model = XGBClassifier(**random_search.best_params_)
model.fit(X_train_res, y_train_res)

y_pred = model.predict(X_test_encoded)
report = classification_report(y_test, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.91      0.95     11390
#            1       0.51      0.98      0.67      1108
#
#     accuracy                           0.91     12498
#    macro avg       0.75      0.94      0.81     12498
# weighted avg       0.95      0.91      0.93     12498

# %% [markdown]
# Optuna uses an efficient approach to find the best parameters using techniques such as Gradient optimization, Bayesian Optimization and Evolutionary Algorithms.
#
# Compared to Hyperparameter Tunning methods like GridSearchCV and RandomizedSearchCV, Optuna offers a more effective solution

# %% [markdown]
# ### Attempt 3
#
# 1. Logistic Regression
# 1. Handle Class Imbalance Using SMOTE Tomek
# 1. Parameter tunning using optuna

# %%
 'class_weight': None}. Best is trial 5 with value: 0.944963548766475.
# [I 2024-08-07 11:26:15,533] Trial 38 finished with value: 0.9446872439786569 and parameters: {'C': 129.6744239221477, 'solver': 'saga', 'tol': 0.0002513130206639243, 'class_weight': None}. Best is trial 5 with value: 0.944963548766475.
# [I 2024-08-07 11:26:16,603] Trial 39 finished with value: 0.9448182240478786 and parameters: {'C': 13.646686299886268, 'solver': 'liblinear', 'tol': 3.429771149364496e-05, 'class_weight': 'balanced'}. Best is trial 5 with value: 0.944963548766475.
# [I 2024-08-07 11:26:17,880] Trial 40 finished with value: 0.9438917738437625 and parameters: {'C': 0.43010919371565176, 'solver': 'saga', 'tol': 1.9789348174400352e-05, 'class_weight': None}. Best is trial 5 with value: 0.944963548766475.
# [I 2024-08-07 11:26:18,632] Trial 41 finished with value: 0.9449199053131018 and parameters: {'C': 3.3981902241298214, 'solver': 'lbfgs', 'tol': 1.2563021990617394e-05, 'class_weight': None}. Best is trial 5 with value: 0.944963548766475.
# [I 2024-08-07 11:26:19,400] Trial 42 finished with value: 0.9448765063389398 and parameters: {'C': 4.359309344745934, 'solver': 'lbfgs', 'tol': 1.1720765422424074e-05, 'class_weight': None}. Best is trial 5 with value: 0.944963548766475.
# [I 2024-08-07 11:26:20,195] Trial 43 finished with value: 0.9447017308373025 and parameters: {'C': 63.210492459884776, 'solver': 'lbfgs', 'tol': 3.8494790813152716e-06, 'class_weight': None}. Best is trial 5 with value: 0.944963548766475.
# [I 2024-08-07 11:26:20,943] Trial 44 finished with value: 0.9445220506765244 and parameters: {'C': 0.7811686115534107, 'solver': 'lbfgs', 'tol': 5.073749831071337e-05, 'class_weight': None}. Best is trial 5 with value: 0.944963548766475.
# [I 2024-08-07 11:26:21,718] Trial 45 finished with value: 0.944876840134155 and parameters: {'C': 9.759362544769761, 'solver': 'lbfgs', 'tol': 0.01142436386951618, 'class_weight': None}. Best is trial 5 with value: 0.944963548766475.
# [I 2024-08-07 11:26:22,622] Trial 46 finished with value: 0.9310462441553184 and parameters: {'C': 0.03400391462667079, 'solver': 'liblinear', 'tol': 2.7688055872806825e-05, 'class_weight': None}. Best is trial 5 with value: 0.944963548766475.
# [I 2024-08-07 11:26:23,710] Trial 47 finished with value: 0.9425128731569631 and parameters: {'C': 0.2173092573280845, 'solver': 'newton-cg', 'tol': 1.7522613299162092e-06, 'class_weight': 'balanced'}. Best is trial 5 with value: 0.944963548766475.
# [I 2024-08-07 11:26:25,392] Trial 48 finished with value: 0.944730859774506 and parameters: {'C': 23.4658150343759, 'solver': 'saga', 'tol': 3.632037956243791e-06, 'class_weight': None}. Best is trial 5 with value: 0.944963548766475.
# [I 2024-08-07 11:26:26,234] Trial 49 finished with value: 0.944745640483716 and parameters: {'C': 272.6972288434953, 'solver': 'lbfgs', 'tol': 9.105877155797237e-06, 'class_weight': None}. Best is trial 5 with value: 0.944963548766475.

# %%
print('Best trial:')
trial = study_logistic.best_trial
print('  F1-score: {}'.format(trial.value))
print('  Params: ')
for key, value in trial.params.items():
    print('    {}: {}'.format(key, value))
    
best_model_logistic = LogisticRegression(**study_logistic.best_params)
best_model_logistic.fit(X_train_smt, y_train_smt)

# Evaluate on the test set
y_pred = best_model_logistic.predict(X_test_encoded)

report = classification_report(y_test, y_pred)
print(report)
# Out:
# Best trial:
#   F1-score: 0.944963548766475
#   Params:
#     C: 2.4921996799409833
#     solver: saga
#     tol: 8.80691186526024e-06
#     class_weight: None
#               precision    recall  f1-score   support
#
#            0       0.99      0.93      0.96     11390
#            1       0.57      0.94      0.71      1108
#
#     accuracy                           0.93     12498
#    macro avg       0.78      0.93      0.83     12498
# weighted avg       0.96      0.93      0.94     12498

# %% [markdown]
# ### Attempt 4
#
# 1. XGBoost
# 1. Handle Class Imbalance Using SMOTE Tomek
# 1. Parameter tunning using optuna

# %%
# Define the objective function for Optuna
def objective(trial):
    param = {
        'objective': 'binary:logistic',
        'eval_metric': 'logloss',
        'verbosity': 0,
        'booster': 'gbtree',
        'lambda': trial.suggest_float('lambda', 1e-3, 10.0, log=True),
        'alpha': trial.suggest_float('alpha', 1e-3, 10.0, log=True),
        'subsample': trial.suggest_float('subsample', 0.4, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.4, 1.0),
        'max_depth': trial.suggest_int('max_depth', 3, 10),
        'eta': trial.suggest_float('eta', 0.01, 0.3),
        'gamma': trial.suggest_float('gamma', 0, 10),
        'scale_pos_weight': trial.suggest_float('scale_pos_weight', 1, 10),
        'min_child_weight': trial.suggest_int('min_child_weight', 1, 10),
        'max_delta_step': trial.suggest_int('max_delta_step', 0, 10)
    }

    model = XGBClassifier(**param)
    
    # Calculate the cross-validated f1_score
    f1_scorer = make_scorer(f1_score, average='macro')
    scores = cross_val_score(model, X_train_smt, y_train_smt, cv=3, scoring=f1_scorer, n_jobs=-1)
    
    return np.mean(scores)

study_xgb = optuna.create_study(direction='maximize')
study_xgb.optimize(objective, n_trials=50)
# Out:
# [I 2024-08-07 11:26:27,755] A new study created in memory with name: no-name-e15e8853-6ab1-48e9-856e-0b505433a3c0
# [I 2024-08-07 11:26:31,300] Trial 0 finished with value: 0.9605270604037895 and parameters: {'lambda': 0.002453934511323946, 'alpha': 1.9928011247472277, 'subsample': 0.8676342472258011, 'colsample_bytree': 0.4809930965306951, 'max_depth': 9, 'eta': 0.22753523576490764, 'gamma': 9.266244453647637, 'scale_pos_weight': 9.747960897610588, 'min_child_weight': 9, 'max_delta_step': 5}. Best is trial 0 with value: 0.9605270604037895.
# [I 2024-08-07 11:26:34,286] Trial 1 finished with value: 0.8956142912277345 and parameters: {'lambda': 0.003588802223704672, 'alpha': 1.0397909163096868, 'subsample': 0.8688721852079775, 'colsample_bytree': 0.9484914884114231, 'max_depth': 3, 'eta': 0.04744541247905584, 'gamma': 8.415436637092439, 'scale_pos_weight': 8.381035917479075, 'min_child_weight': 7, 'max_delta_step': 8}. Best is trial 0 with value: 0.9605270604037895.
# [I 2024-08-07 11:26:38,540] Trial 2 finished with value: 0.9663346293681295 and parameters: {'lambda': 0.0034412691093921896, 'alpha': 0.0013665625740832954, 'subsample': 0.8776701412688619, 'colsample_bytree': 0.7152776484728471, 'max_depth': 7, 'eta': 0.12832050321190497, 'gamma': 1.7700910259952696, 'scale_pos_weight': 5.616144067557486, 'min_child_weight': 7, 'max_delta_step': 2}. Best is trial 2 with value: 0.9663346293681295.
# [I 2024-08-07 11:26:42,050] Trial 3 finished with value: 0.9679706480792473 and parameters: {'lambda': 0.4250059602478993, 'alpha': 1.3760707682711522, 'subsample': 0.6955879627365504, 'colsample_bytree': 0.7103790074986396, 'max_depth': 5, 'eta': 0.13729019760602423, 'gamma': 0.18848597187926197, 'scale_pos_weight': 1.5362201383165788, 'min_child_weight': 1, 'max_delta_step': 2}. Best is trial 3 with value: 0.9679706480792473.
# [I 2024-08-07 11:26:45,880] Trial 4 finished with value: 0.964621515474145 and parameters: {'lambda': 0.1213383610661013, 'alpha': 1.9555264962933547, 'subsample': 0.4793768308402829, 'colsample_bytree': 0.5961676730253135, 'max_depth': 8, 'eta': 0.20146618915927553, 'gamma': 4.848984451028624, 'scale_pos_weight': 5.74580977838306, 'min_child_weight': 7, 'max_delta_step': 9}. Best is trial 3 with value: 0.9679706480792473.
# [I 2024-08-07 11:26:48,830] Trial 5 finished with value: 0.8947869678967063 and parameters: {'lambda': 0.005426772948194737, 'alpha': 0.3201327780266304, 'subsample': 0.7507282893143643, 'colsample_bytree': 0.5990026417177186, 'max_depth': 3, 'eta': 0.05878954413016397, 'gamma': 6.726402029109497, 'scale_pos_weight': 7.01312930554128, 'min_child_weight': 9, 'max_delta_step': 7}. Best is trial 3 with value: 0.9679706480792473.
# [I 2024-08-07 11:26:52,859] Trial 6 finished with value: 0.9400792436799432 and parameters: {'lambda': 0.12268700194227086, 'alpha': 0.03583969970534751, 'subsample': 0.6772568336611082, 'colsample_bytree': 0.5552148118559909, 'max_depth': 6, 'eta': 0.07324500033531028, 'gamma': 2.1157121964787806, 'scale_pos_weight': 8.055828585727026, 'min_child_weight': 10, 'max_delta_step': 5}. Best is trial 3 with value: 0.9679706480792473.
# [I 2024-08-07 11:26:56,430] Trial 7 finished with value: 0.96739332058772 and parameters: {'lambda': 1.4016209471746646, 'alpha': 0.021022379872478934, 'subsample': 0.40839081527612026, 'colsample_bytree': 0.9652828626419462, 'max_depth': 10, 'eta': 0.2550179731419325, 'gamma': 5.61979202654239, 'scale_pos_weight': 6.720155708138071, 'min_child_weight': 5, 'max_delta_step': 3}. Best is trial 3 with value: 0.9679706480792473.
# [I 2024-08-07 11:27:00,249] Trial 8 finished with value: 0.9361828496953098 and parameters: {'lambda': 0.06540878888503385, 'alpha': 6.513653656711147, 'subsample': 0.6876999159719631, 'colsample_bytree': 0.7695797714329771, 'max_depth': 5, 'eta': 0.05652822411816582, 'gamma': 7.89410694681714, 'scale_pos_weight': 6.491174086108804, 'min_child_weight': 8, 'max_delta_step': 2}. Best is trial 3 with value: 0.9679706480792473.
# [I 2024-08-07 11:27:03,195] Trial 9 finished with value: 0.9539601398334773 and parameters: {'lambda': 0.009393814214262403, 'alpha': 1.0959625061904674, 'subsample': 0.9062661630812918, 'colsample_bytree': 0.8766796834006134, 'max_depth': 3, 'eta': 0.1060959563847493, 'gamma': 7.372096696582688, 'scale_pos_weight': 1.889659922577055, 'min_child_weight': 2, 'max_delta_step': 3}. Best is trial 3 with value: 0.9679706480792473.
# [I 2024-08-07 11:27:06,853] Trial 10 finished with value: 0.9691020808982058 and parameters: {'lambda': 9.241510228585383, 'alpha': 0.12900740321914353, 'subsample': 0.540253824532356, 'colsample_bytree': 0.7961950026774931, 'max_depth': 5, 'eta': 0.17472993766334005, 'gamma': 0.10584563010768124, 'scale_pos_weight': 1.203526584563397, 'min_child_weight': 1, 'max_delta_step': 0}. Best is trial 10 with value: 0.9691020808982058.
# [I 2024-08-07 11:27:10,579] Trial 11 finished with value: 0.969585923498815 and parameters: {'lambda': 5.926167288345429, 'alpha': 0.13122100512295792, 'subsample': 0.5580265049038498, 'colsample_bytree': 0.811831484563259, 'max_depth': 5, 'eta': 0.16148396644691135, 'gamma': 0.23904124712798197, 'scale_pos_weight': 1.1550760390788157, 'min_child_weight': 1, 'max_delta_step': 0}. Best is trial 11 with value: 0.969585923498815.
# [I 2024-08-07 11:27:14,316] Trial 12 finished with value: 0.9645509528802836 and parameters: {'lambda': 7.67918058690862, 'alpha': 0.12019758226281203, 'subsample': 0.5381616982167217, 'colsample_bytree': 0.8191526273197242, 'max_depth': 5, 'eta': 0.1834280898901211, 'gamma': 0.43078690930149366, 'scale_pos_weight': 3.2114061148853676, 'min_child_weight': 3, 'max_delta_step': 0}. Best is trial 11 with value: 0.969585923498815.
# [I 2024-08-07 11:27:18,008] Trial 13 finished with value: 0.9692980806777408 and parameters: {'lambda': 9.665043639171254, 'alpha': 0.008232885527187933, 'subsample': 0.5668268029550199, 'colsample_bytree': 0.8731467467031819, 'max_depth': 6, 'eta': 0.2897992120002366, 'gamma': 3.3551094932182424, 'scale_pos_weight': 3.6886118003495487, 'min_child_weight': 4, 'max_delta_step': 0}. Best is trial 11 with value: 0.969585923498815.
# [I 2024-08-07 11:27:21,752] Trial 14 finished with value: 0.971657363189898 and parameters: {'lambda': 2.2962008456177116, 'alpha': 0.00445389632831057, 'subsample': 0.5961724003504207, 'colsample_bytree': 0.8789213465747236, 'max_depth': 7, 'eta': 0.29385434545747535, 'gamma': 3.101837916689985, 'scale_pos_weight': 3.862135954568061, 'min_child_weight': 4, 'max_delta_step': 0}. Best is trial 14 with value: 0.971657363189898.
# [I 2024-08-07 11:27:25,485] Trial 15 finished with value: 0.9710569765450755 and parameters: {'lambda': 1.6160071497314137, 'alpha': 0.0012720266695814533, 'subsample': 0.6028727299229769, 'colsample_bytree': 0.8885039210631882, 'max_depth': 7, 'eta': 0.2898758786585631, 'gamma': 3.6116479028836874, 'scale_pos_weight': 4.113042649023732, 'min_child_weight': 3, 'max_delta_step': 1}. Best is trial 14 with value: 0.971657363189898.
# [I 2024-08-07 11:27:28,962] Trial 16 finished with value: 0.9707489927248151 and parameters: {'lambda': 1.5130809420223699, 'alpha': 0.0011343234200556788, 'subsample': 0.6192069924786069, 'colsample_bytree': 0.9067721906664862, 'max_depth': 8, 'eta': 0.287616578976384, 'gamma': 3.8750642395875525, 'scale_pos_weight': 4.030787484298736, 'min_child_weight': 4, 'max_delta_step': 4}. Best is trial 14 with value: 0.971657363189898.
# [I 2024-08-07 11:27:32,680] Trial 17 finished with value: 0.9712309484351068 and parameters: {'lambda': 1.4497355499772346, 'alpha': 0.004481167343662348, 'subsample': 0.7906260750691992, 'colsample_bytree': 0.9921601142532245, 'max_depth': 7, 'eta': 0.24808653945988196, 'gamma': 2.920834442778365, 'scale_pos_weight': 4.548808040757722, 'min_child_weight': 5, 'max_delta_step': 1}. Best is trial 14 with value: 0.971657363189898.
# [I 2024-08-07 11:27:36,629] Trial 18 finished with value: 0.9723451029906963 and parameters: {'lambda': 0.41562690834162563, 'alpha': 0.004916403066440938, 'subsample': 0.7918201904823747, 'colsample_bytree': 0.9949768296933958, 'max_depth': 8, 'eta': 0.2446943914339901, 'gamma': 2.10591980565573, 'scale_pos_weight': 4.758582648468121, 'min_child_weight': 5, 'max_delta_step': 7}. Best is trial 18 with value: 0.9723451029906963.
 'min_child_weight': 8, 'max_delta_step': 9}. Best is trial 24 with value: 0.9747901192769909.
# [I 2024-08-07 11:28:18,242] Trial 27 finished with value: 0.9516664757604136 and parameters: {'lambda': 0.00127372679105507, 'alpha': 0.3299297807906655, 'subsample': 0.9385475717794146, 'colsample_bytree': 0.6360330306598625, 'max_depth': 10, 'eta': 0.02147351661543781, 'gamma': 0.7349723722316671, 'scale_pos_weight': 2.227979610923539, 'min_child_weight': 7, 'max_delta_step': 9}. Best is trial 24 with value: 0.9747901192769909.
# [I 2024-08-07 11:28:22,809] Trial 28 finished with value: 0.9725849158464718 and parameters: {'lambda': 0.007744415957762047, 'alpha': 0.05062959092352857, 'subsample': 0.8274071649912155, 'colsample_bytree': 0.5049697621185325, 'max_depth': 9, 'eta': 0.1100776139409893, 'gamma': 2.617251668460237, 'scale_pos_weight': 1.0337359926300098, 'min_child_weight': 8, 'max_delta_step': 8}. Best is trial 24 with value: 0.9747901192769909.
# [I 2024-08-07 11:28:27,359] Trial 29 finished with value: 0.9673757354158258 and parameters: {'lambda': 0.0022504479286754335, 'alpha': 0.32626772875829124, 'subsample': 0.938608626158068, 'colsample_bytree': 0.47277266765101583, 'max_depth': 8, 'eta': 0.17503676681738345, 'gamma': 0.9370880309991334, 'scale_pos_weight': 9.700367510493694, 'min_child_weight': 6, 'max_delta_step': 6}. Best is trial 24 with value: 0.9747901192769909.
# [I 2024-08-07 11:28:30,879] Trial 30 finished with value: 0.9656510630977415 and parameters: {'lambda': 0.001760021442334539, 'alpha': 0.06168743838884299, 'subsample': 0.839563287253539, 'colsample_bytree': 0.5366418172700957, 'max_depth': 10, 'eta': 0.23466241681081415, 'gamma': 9.710833044727929, 'scale_pos_weight': 3.451587138761064, 'min_child_weight': 9, 'max_delta_step': 10}. Best is trial 24 with value: 0.9747901192769909.
# [I 2024-08-07 11:28:35,443] Trial 31 finished with value: 0.973283938071147 and parameters: {'lambda': 0.012686246599784685, 'alpha': 0.02319306631847013, 'subsample': 0.9511439464664151, 'colsample_bytree': 0.4098524894251649, 'max_depth': 9, 'eta': 0.19103912606244702, 'gamma': 1.0560638243722111, 'scale_pos_weight': 2.4355183223448873, 'min_child_weight': 6, 'max_delta_step': 10}. Best is trial 24 with value: 0.9747901192769909.
# [I 2024-08-07 11:28:39,684] Trial 32 finished with value: 0.9729475220658766 and parameters: {'lambda': 0.06806791449984975, 'alpha': 0.010390847302762175, 'subsample': 0.9131057499253293, 'colsample_bytree': 0.45863266195307717, 'max_depth': 9, 'eta': 0.1584197915528736, 'gamma': 2.601534259535853, 'scale_pos_weight': 1.7913913900940535, 'min_child_weight': 7, 'max_delta_step': 8}. Best is trial 24 with value: 0.9747901192769909.
# [I 2024-08-07 11:28:44,002] Trial 33 finished with value: 0.9710280863119847 and parameters: {'lambda': 0.0038287755406527474, 'alpha': 0.030729392332057404, 'subsample': 0.9678186578929837, 'colsample_bytree': 0.43461162374166634, 'max_depth': 8, 'eta': 0.22375397987946907, 'gamma': 1.1564288518997086, 'scale_pos_weight': 4.821733068217161, 'min_child_weight': 5, 'max_delta_step': 9}. Best is trial 24 with value: 0.9747901192769909.
# [I 2024-08-07 11:28:48,075] Trial 34 finished with value: 0.9727859381449862 and parameters: {'lambda': 0.01594271889684525, 'alpha': 0.2076227697158512, 'subsample': 0.8764842932862558, 'colsample_bytree': 0.4845452856284288, 'max_depth': 10, 'eta': 0.2673758007139257, 'gamma': 2.2528604969632497, 'scale_pos_weight': 3.1197975072030513, 'min_child_weight': 7, 'max_delta_step': 10}. Best is trial 24 with value: 0.9747901192769909.
# [I 2024-08-07 11:28:52,538] Trial 35 finished with value: 0.9753614277799899 and parameters: {'lambda': 0.002797609468341665, 'alpha': 0.08611702809398432, 'subsample': 0.9969188728490913, 'colsample_bytree': 0.5536200189885964, 'max_depth': 9, 'eta': 0.19516569126645464, 'gamma': 1.326233659563395, 'scale_pos_weight': 1.6375563395421595, 'min_child_weight': 6, 'max_delta_step': 8}. Best is trial 35 with value: 0.9753614277799899.
# [I 2024-08-07 11
 'min_child_weight': 9, 'max_delta_step': 9}. Best is trial 35 with value: 0.9753614277799899.
# [I 2024-08-07 11:29:37,827] Trial 45 finished with value: 0.9665226327195434 and parameters: {'lambda': 0.003501236374891585, 'alpha': 0.007548964634528775, 'subsample': 0.6440346887352063, 'colsample_bytree': 0.6081020419257874, 'max_depth': 4, 'eta': 0.19692633716699584, 'gamma': 0.32398572312882257, 'scale_pos_weight': 1.4714008435304338, 'min_child_weight': 10, 'max_delta_step': 8}. Best is trial 35 with value: 0.9753614277799899.
# [I 2024-08-07 11:29:41,700] Trial 46 finished with value: 0.9725252835873892 and parameters: {'lambda': 0.009123622865678726, 'alpha': 0.16188440815982397, 'subsample': 0.7413141808491783, 'colsample_bytree': 0.6308792769515534, 'max_depth': 6, 'eta': 0.22966561895778428, 'gamma': 0.5710761282304602, 'scale_pos_weight': 1.5231856792004075, 'min_child_weight': 9, 'max_delta_step': 9}. Best is trial 35 with value: 0.9753614277799899.
# [I 2024-08-07 11:29:46,402] Trial 47 finished with value: 0.9726961970571458 and parameters: {'lambda': 0.004419379363018127, 'alpha': 0.48183634529021224, 'subsample': 0.7095967367369295, 'colsample_bytree': 0.5455123703060359, 'max_depth': 8, 'eta': 0.21459488055006123, 'gamma': 0.08564043031965513, 'scale_pos_weight': 3.307656368894142, 'min_child_weight': 8, 'max_delta_step': 6}. Best is trial 35 with value: 0.9753614277799899.
# [I 2024-08-07 11:29:50,837] Trial 48 finished with value: 0.9697069335858327 and parameters: {'lambda': 0.002550588947818854, 'alpha': 0.012445608951177497, 'subsample': 0.45846114191577614, 'colsample_bytree': 0.6694535045191105, 'max_depth': 8, 'eta': 0.2661727639201472, 'gamma': 2.0554326317942104, 'scale_pos_weight': 8.582666260724896, 'min_child_weight': 8, 'max_delta_step': 8}. Best is trial 35 with value: 0.9753614277799899.
# [I 2024-08-07 11:29:55,741] Trial 49 finished with value: 0.9732084027557772 and parameters: {'lambda': 0.006219718724334723, 'alpha': 3.960526573610206, 'subsample': 0.6567474121720963, 'colsample_bytree': 0.7323449547193309, 'max_depth': 9, 'eta': 0.19378681430871236, 'gamma': 0.6187289173814499, 'scale_pos_weight': 2.3397376214552255, 'min_child_weight': 7, 'max_delta_step': 9}. Best is trial 35 with value: 0.9753614277799899.

# %%
print('Best trial:')
trial = study_xgb.best_trial
print('  F1-score: {}'.format(trial.value))
print('  Params: ')
for key, value in trial.params.items():
    print('    {}: {}'.format(key, value))
    
best_params = study_xgb.best_params
best_model_xgb = XGBClassifier(**best_params)
best_model_xgb.fit(X_train_smt, y_train_smt)

# Evaluate on the test set
y_pred = best_model_xgb.predict(X_test_encoded)

report = classification_report(y_test, y_pred)
print(report)
# Out:
# Best trial:
#   F1-score: 0.9753614277799899
#   Params:
#     lambda: 0.002797609468341665
#     alpha: 0.08611702809398432
#     subsample: 0.9969188728490913
#     colsample_bytree: 0.5536200189885964
#     max_depth: 9
#     eta: 0.19516569126645464
#     gamma: 1.326233659563395
#     scale_pos_weight: 1.6375563395421595
#     min_child_weight: 6
#     max_delta_step: 8
#               precision    recall  f1-score   support
#
#            0       0.99      0.97      0.98     11390
#            1       0.73      0.86      0.79      1108
#
#     accuracy                           0.96     12498
#    macro avg       0.86      0.91      0.88     12498
# weighted avg       0.96      0.96      0.96     12498

# %% [markdown]
# ## Model Evaluation : ROC/AUC

# %%
y_pred = best_model_logistic.predict(X_test_encoded)
report = classification_report(y_test, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.93      0.96     11390
#            1       0.57      0.94      0.71      1108
#
#     accuracy                           0.93     12498
#    macro avg       0.78      0.93      0.83     12498
# weighted avg       0.96      0.93      0.94     12498

# %%
from sklearn.metrics import roc_curve

probabilities = best_model_logistic.predict_proba(X_test_encoded)[:,1]
fpr, tpr, thresholds = roc_curve(y_test, probabilities)

fpr[:5], tpr[:5], thresholds[:5]
# Out:
# (array([0.       , 0.       , 0.       , 0.0000878, 0.0000878]),
#  array([0.        , 0.00090253, 0.20758123, 0.20758123, 0.22833935]),
#  array([1.99999992, 0.99999992, 0.99868643, 0.99864624, 0.99831369]))

# %%
from sklearn.metrics import auc

area = auc(fpr, tpr)
area
# Out:
# 0.983006659207678

# %%
plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % area)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# ## Model Evaluation : Rankordering, KS statistic, Gini coeff

# %% [markdown]
# - Rank ordering and KS statistics are crucial metrics used to evaluate performance of real world credit risk models.
# - The process involves sorting borrowers by predicted default probabilities and observing actual defaults in grouped segments like deciles.
# - The KS statistic measures the maximum difference in cumulative distributions of defaulters versus non-defaulters, indicating model discrimination quality.
# - A high KS value suggests strong model performance, with clear separation between high-risk and low-risk borrowers. KS value of more than 40 is considered a good model.

# %%
probabilities = best_model_logistic.predict_proba(X_test_encoded)[:,1]

df_eval = pd.DataFrame({
    'Default Truth': y_test,
    'Default Probability': probabilities
})
df_eval.head(3)
# Out:
#        Default Truth  Default Probability
#
000
# 8       1                0.000                0.000   0.000    1250.000
# 9       0                0.000                0.000   0.000    1250.000
#
#    Event Rate  Non-event Rate  Cum Events  Cum Non-events  Cum Event Rate  \
# 0      73.440          26.560     918.000         332.000          82.852
# 1      13.520          86.480    1087.000        1413.000          98.105
# 2       1.440          98.560    1105.000        2645.000          99.729
# 3       0.160          99.840    1107.000        3892.000          99.910
# 4       0.080          99.920    1108.000        5141.000         100.000
# 5       0.000         100.000    1108.000        6391.000         100.000
# 6       0.000         100.000    1108.000        7640.000         100.000
# 7       0.000         100.000    1108.000        8890.000         100.000
# 8       0.000         100.000    1108.000       10140.000         100.000
# 9       0.000         100.000    1108.000       11390.000         100.000
#
#    Cum Non-event Rate     KS
# 0               2.915 79.937
# 1              12.406 85.699
# 2              23.222 76.507
# 3              34.170 65.739
# 4              45.136 54.864
# 5              56.111 43.889
# 6              67.076 32.924
# 7              78.051 21.949
# 8              89.025 10.975
# 9             100.000  0.000

# %% [markdown]
# To assess whether rank ordering is followed, we should look at whether higher deciles (those with higher predicted probabilities) have higher event rates compared to lower deciles. Rank ordering means that as you move from the top decile to the bottom decile, the event rate should generally decrease.
#
# Non-Events - termed as good (customers) who do not default. Events - termed as bad (customers) who default.
#
# Events and Non-Events terms are interchanged based on usecase to usecase.
#
# eg: for marketing usecase, which customer to reach out (who will take loan based on offers) will be events - here it will termed as good, and the customers who will not take loans will be non-events (bad).
#
# **Insights from the Decile Table**
#
# 1. Top Deciles
#
# * The first decile (Decile 9) has a high event rate of 72.00% and a non-event rate of 28.00%. This indicates that the model is highly confident in predicting events in this decile.
# * The second decile (Decile 8) also shows a significant event rate of 12.72%, with a cumulative event rate reaching 98.6%.
#
# 2. Middle Deciles:
#
# * Deciles 7 and 6 show a significant drop in event rates
#
# 3. Lower Deciles:
#
# * Deciles 5 to 0 show zero events, with all predictions being non-events. These deciles collectively have a non-event rate of 100%.
#
# 4. KS Statistic:
#
# * The KS statistic, which is the maximum difference between cumulative event rates and cumulative non-event rates, is highest at Decile 8 with a value of 85.98%. This suggests that the model performs best at distinguishing between events and non-events up to this decile.
#
# * The KS value gradually decreases in the following deciles, indicating a decrease in model performance for distinguishing between events and non-events.
#
# **KS Value**
#
# The highest KS value is 85.98%, found at Decile 8. This indicates that the model's performance in distinguishing between events and non-events is most significant at this decile. (If KS is in top 3 decile and score above 40, it is considered a good predictive model.)

# %%
gini_coefficient = 2 * area - 1

print("AUC:", area)
print("Gini Coefficient:", gini_coefficient)
# Out:
# AUC: 0.983006659207678
# Gini Coefficient: 0.9660133184153561

# %% [markdown]
# AUC of 0.98: The model is very good at distinguishing between events and non-events.
#
# Gini coefficient of 0.96: This further confirms that the model is highly effective in its predictions, with almost perfect rank ordering capability.
#
# The Gini coefficient ranges from -1 to 1, where a value closer to 1 signifies a perfect model, 0 indicates a model with no discriminative power, and -1 signifies a perfectly incorrect model.

# %% [markdown]
# #### Finalize The Model and Visualize Feature Importance

# %%
final_model = best_model_logistic

feature_importance = final_model.coef_[0]

# Create a DataFrame for easier handling
coef_df = pd.DataFrame(feature_importance, index=X_train_encoded.columns, columns=['Coefficients'])

# Sort the coefficients for better visualization
coef_df = coef_df.sort_values(by='Coefficients', ascending=True)

# Plotting
plt.figure(figsize=(8, 4))
plt.barh(coef_df.index, coef_df['Coefficients'], color='steelblue')
plt.xlabel('Coefficient Value')
plt.title('Feature Importance in Logistic Regression')
plt.show()

# %% [markdown]
# ### Saving the Model

# %%
X_test_encoded.head(2)
# Out:
#         age  loan_tenure_months  number_of_open_accounts  \
# 33553 0.346               0.528                    0.333
# 9427  0.288               0.623                    1.000
#
#        credit_utilization_ratio  loan_to_income  delinquency_ratio  \
# 33553                     0.121           0.258              0.043
# 9427                      0.859           0.689              0.000
#
#        avg_dpd_per_delinquency  residence_type_Owned  residence_type_Rented  \
# 33553                    0.900                     1                      0
# 9427                     0.000                     1                      0
#
#        loan_purpose_Education  loan_purpose_Home  loan_purpose_Personal  \
# 33553                       1                  0                      0
# 9427                        0                  1                      0
#
#        loan_type_Unsecured
# 33553                    0
# 9427                     0

# %%
X_test_encoded.columns
# Out:
# Index(['age', 'loan_tenure_months', 'number_of_open_accounts',
#        'credit_utilization_ratio', 'loan_to_income', 'delinquency_ratio',
#        'avg_dpd_per_delinquency', 'residence_type_Owned',
#        'residence_type_Rented', 'loan_purpose_Education', 'loan_purpose_Home',
#        'loan_purpose_Personal', 'loan_type_Unsecured'],
#       dtype='object')

# %%
cols_to_scale
# Out:
# Index(['age', 'number_of_dependants', 'years_at_current_address', 'zipcode',
#        'sanction_amount', 'processing_fee', 'gst', 'net_disbursement',
#        'loan_tenure_months', 'principal_outstanding',
#        'bank_balance_at_application', 'number_of_open_accounts',
#        'number_of_closed_accounts', 'enquiry_count',
#        'credit_utilization_ratio', 'loan_to_income', 'delinquency_ratio',
#        'avg_dpd_per_delinquency'],
#       dtype='object')

# %%
X_train_encoded.columns
# Out:
# Index(['age', 'loan_tenure_months', 'number_of_open_accounts',
#        'credit_utilization_ratio', 'loan_to_income', 'delinquency_ratio',
#        'avg_dpd_per_delinquency', 'residence_type_Owned',
#        'residence_type_Rented', 'loan_purpose_Education', 'loan_purpose_Home',
#        'loan_purpose_Personal', 'loan_type_Unsecured'],
#       dtype='object')

# %%
from joblib import dump

model_data = {
    'model': final_model,
    'features': X_train_encoded.columns,
    'scaler': scaler,
    'cols_to_scale': cols_to_scale
}
dump(model_data, 'artifacts/model_data.joblib')
# Out:
# ['artifacts/model_data.joblib']

# %%
final_model.coef_, final_model.intercept_
# Out:
# (array([[ 0.04338347,  0.75700275,  1.00396212, 15.51135419, 17.02704305,
#          13.13913241,  1.92246076, -1.83268136,  1.84403547,  0.94566771,
#          -3.28166749,  1.08803507,  1.08803507]]),
#  array([-20.25506928]))
